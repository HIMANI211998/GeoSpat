# %% [markdown]
# ## Simple Classification Problem

# %%
from pycaret.datasets import get_data

# %%
diabetes_df=get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
from pycaret.classification import *
cf=setup(data=diabetes_df,target='Class variable')
# Out:
# <style  type="text/css" >
# </style><table id="T_a9b3baf4_4758_11eb_a618_548ca07ec436" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a9b3baf4_4758_11eb_a618_548ca07ec436level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a9b3baf4_4758_11eb_a618_548ca07ec436row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_a9b3baf4_4758_11eb_a618_548ca07ec436row0_col1" class="data row0 col1" >7481</td>
#             </tr>
#             <tr>
#                         <th id="T_a9b3baf4_4758_11eb_a618_548ca07ec436level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a9b3baf4_4758_11eb_a618_548ca07ec436row1_col0" class="data row1 col0" >Target</td>
# ...

# %% [markdown]
# ## Compare Models

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_24f007ff_475a_11eb_888c_548ca07ec436 th {
#           text-align: left;
# ...

# %% [markdown]
# ## Regression

# %%
boston_df=get_data('boston')
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from pycaret.regression import *

# %%
reg=setup(data=boston_df,target='medv')
# Out:
# <style  type="text/css" >
# </style><table id="T_cb0d91f1_475c_11eb_ae14_548ca07ec436" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cb0d91f1_475c_11eb_ae14_548ca07ec436level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cb0d91f1_475c_11eb_ae14_548ca07ec436row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_cb0d91f1_475c_11eb_ae14_548ca07ec436row0_col1" class="data row0 col1" >2819</td>
#             </tr>
#             <tr>
#                         <th id="T_cb0d91f1_475c_11eb_ae14_548ca07ec436level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cb0d91f1_475c_11eb_ae14_548ca07ec436row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_0ccf27c2_475d_11eb_b255_548ca07ec436 th {
#           text-align: left;
# ...

# %% [markdown]
# ## So catboost works perfectly. So we will use that model.Refer pycaret.create_model website
# ## For Further syntax
# ### https://pycaret.org/create-model/

# %%
reg_model=create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_8e1cf668_475d_11eb_b786_548ca07ec436row10_col0,#T_8e1cf668_475d_11eb_b786_548ca07ec436row10_col1,#T_8e1cf668_475d_11eb_b786_548ca07ec436row10_col2,#T_8e1cf668_475d_11eb_b786_548ca07ec436row10_col3,#T_8e1cf668_475d_11eb_b786_548ca07ec436row10_col4,#T_8e1cf668_475d_11eb_b786_548ca07ec436row10_col5{
#             background:  yellow;
#         }</style><table id="T_8e1cf668_475d_11eb_b786_548ca07ec436" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8e1cf668_475d_11eb_b786_548ca07ec436level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
reg_model
